# %% [markdown]
# <a href="https://colab.research.google.com/github/orital04/tinyProject2OriTal/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# מייבאים את הספריות שאנחנו צריכים

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-710cb351-5e21-4db1-a577-fc465847f6b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-710cb351-5e21-4db1-a577-fc465847f6b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes.csv

# %% [markdown]
# מייבאים את בסיס הנתונים שלנו, שומרים אותו במשנה ומציגים את הנתונים.

# %%
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# נציג את מערך הנתונים, ואת המימדים שלו

# %%
print(df.head())
print(df.shape)
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]
# (768, 9)

# %% [markdown]
# נציג מידע על מערך הנתונים, ונבדוק האם יש לנו משתנים לא מספריים.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# במקרה נחתתי על מערך נתונים בלי משתנים קטגוריאלים אלא רק מספריים. פחות עבודה בשבילי :)

# %% [markdown]
# נציג עכשיו נתונים מתמטים שונים על המשתנים כמו ממוצע כמות משתנה מקסימלי ועוד...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# נבדוק בעמודה שאנחנו רוצים לחזות, כמה מתוכם חולים בסכרת וכמה לא כי למה לא.

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# בשלב הזה גיליתי את ההיטמאפ אז ככה הצגתי את הנתונים כדי לראות קשרים בינהם והאם יש נתונים שאפשר להוריד, כי הקשר שלהם עם עמודת החיזוי לא חזק מספיק

# %%
colormap = plt.cm.PuBu 
plt.figure(figsize=(10, 8)) 
plt.title("Diabetes Correlation of Features", y = 1.05, size = 15) 
sns.heatmap(df.astype(float).corr(), linewidths = 0.1, vmax = 1.0, 
            square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 16})

# %% [markdown]
# כדי לבדוק את הקשר נסתכל על הטור הכי ימני ונראה האם יש קשר שלא חזק מספיק. בגלל שהקשר הכי חלש היה 0.065 והוא לדעתי עדיין קשר חזק מספיק שאי אפשר להתעלם ממנו, החלטתי לא להוריד את אף אחד מהעמודות.

# %% [markdown]
# עכשיו, נגדיר את המשתנים איקס וואי כך שהוואי הוא מה שאנחנו מנסים לחזות, והאיקס הוא הכל חוץ מזה.

# %%
X = df.drop(['Outcome'], axis=1)
y = df['Outcome']

# %% [markdown]
# עכשיו נחלק את הנתונים שלנו לטסט ולטריין כדי לאמן את המודל.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train.shape, X_test.shape
# Out:
# ((614, 8), (154, 8))

# %% [markdown]
# בשתי בלוקי הקוד הקרובים בדקתי האם יש לי במערך הנתונים מקומות חסרים בהם מישהו בטעות לא הכניס מספר.

# %%
numerical = [col for col in X_train.columns if X_train[col].dtypes != 'O']
X_train[numerical].isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
X_test[numerical].isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %% [markdown]
# איזה כיף! לא היו אף משתנים חסרים במערך הנתונים שלי ואני יכול להמשיך הלאה לחלק המעניין...

# %% [markdown]
# ייבוא הספריות המתאימות (ייבאתי חלק מהספריות פעמיים כי אני טיפ עייף ועצלן עכשיו)

# %%
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# פיצול לטריין וטסט

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
X_train.shape, X_test.shape
# Out:
# ((514, 8), (254, 8))

# %% [markdown]
# השמה במשתנה את מספר הפיצרים של הקלטים

# %%
n_features = X_train.shape[1]
n_features
# Out:
# 8

# %% [markdown]
# בניית המודל והוספת השכבות עם פונקציות ההפעלה המתאימות וכמות הנוירונים המתאימה

# %%
model = Sequential()
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', input_shape=(n_features,)))
model.add(Dense(8, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# הגדרת פונקציית ההפסד/מחיר, האופטימייזר והמטריקס

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# אימון המודל

# %%
model.fit(X_train, y_train, epochs=400, batch_size=32, verbose=0)

# %% [markdown]
# השמה במשתנים את הדיוק והלוס של המודל, והדפסת הדיוק שלו

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
acc
# Out:
# 0.7244094610214233
